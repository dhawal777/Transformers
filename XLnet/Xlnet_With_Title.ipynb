# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
# !pip install simpletransformers

# %%
import pandas as pd
from simpletransformers.model import TransformerModel
import traceback

# %%
os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

# %%
os.listdir('../input/title-inc/')

# %%
df = pd.read_csv('../input/title-inc/dataset.tsv',sep='\t',header=None,names=['title', 'text','label'])

# %%
df

# %%
df['title'] = df['title'].str.replace('http\S+|www.\S+', '', case=False)

# %%
df['text'] = df['text'].str.replace('@', '', case=False)

# %%
df['text'] = df['text'].str.replace('http\S+|www.\S+', '', case=False)

# %%
df['text']=df['title']+df['text']

# %%
df['text']

# %%
df

# %%
args = {
   'output_dir': 'output/',
   'cache_dir': 'cache/',
   'fp16': False,
   'fp16_opt_level': 'O1',
   'max_seq_length': 128,
   'train_batch_size': 8,
   'eval_batch_size': 8,
   'gradient_accumulation_steps': 1,
   'num_train_epochs': 2,
   'weight_decay': 0,
   'learning_rate': 3e-5,
   'adam_epsilon': 1e-8,
   'warmup_ratio': 0.06,
   'warmup_steps': 0,
   'max_grad_norm': 1.0,'logging_steps': 50,
   'evaluate_during_training': False,
   'save_steps': 2000,
   'eval_all_checkpoints': True,
   'use_tensorboard': True,'overwrite_output_dir': False,
   'reprocess_input_data': False,
#     'num_labels' : 4
}

# %%
data = []
for i,val in df.iterrows():
#     print(val[1])
#     print("cccc")
    try:
        data.append(list([val[1],int(val[2])]))
    except:
        pass

# %%
data

# %%
model = TransformerModel('xlnet','xlnet-base-cased',args=args,use_cuda=False,num_labels=4)
# TransformerModel()

# %%
train_df = pd.DataFrame(data)
try:
    model.train_model(train_df)
except:
    traceback.print_exc()

# %%
# df=df.drop(['title'],axis=1)

# %%
df

# %%
# print(len(df))

# %%
# data = []
# for i,val in df.iterrows():
   
#     try:
# #         print("i ",i,"val ",val[0])
# #         w=list()
#         data.append(list([val[0],int(val[1])]))
# #         print(data)
#     except:
#         pass

# %%
# len(data)

# %%
# model.train_model(df)

# %%
print("Done")
# train_df.shape

# %%
# x = [['jatin',0],['omkar',1],['dhawal',3],['xyz',1]]
import pickle
with open('./output/model.pkl','wb') as f:
    pickle.dump(model,f)

# %%
import os

os.listdir('../input/model-xlnet/output')

# %%
import pickle

# %%
# os.chdir('..')

# %%
# os.chdir('..')

# %%
os.listdir("")

# %%
import pickle

# %%
! pip install pytorch_pretrained_bert

# %%
with open('../input/model-xlnet/output/model.pkl','rb') as f:
    mod=pickle.load(f)

# %%
df_test = pd.read_csv('../input/ire-major/dataset_test.tsv',sep='\t',header=None)

# %%
# data_test = []
# for i,val in df_test.iterrows():
#     try:
#         data_test.append(list([val[2],int(val[1])]))
#     except:
#         pass

# %%
os.listdir('../input/title-inc')

# %%
result=mod.predict(df_test[2])

# %%
mod.predict(['dhawal'])
