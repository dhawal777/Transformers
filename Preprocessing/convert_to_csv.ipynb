# %%
import json
import pandas as pd
import os

# %%
files1 = os.listdir('rumoureval-2019-training-data/twitter-english/')
rootdir = 'rumoureval-2019-training-data/twitter-english/'

# %%
ids = []
text = []
labels = []

for file1 in files1:
    path1 = os.path.join(rootdir,file1)
    try:
        files2 = os.listdir(path1)
    except:
        print(file1)
        continue
    for file2 in files2:
        path3 = os.path.join(path1,file2+'/source-tweet')
        path4 = os.path.join(path1,file2+'/replies')
        try:
            source = os.listdir(path3)
            replies = os.listdir(path4)
        except:
            continue
#         with open(os.path.join(path3,source[0]),'rb') as f:
#             tweet = json.load(f)
#         ids.append(tweet['id'])
#         text.append(tweet['text'])
        for reply in replies:
            with open(os.path.join(path4,reply),'rb') as f:
                tweet = json.load(f)
            ids.append(tweet['id_str'])
            text.append(tweet['text'])
# Out:
# .DS_Store

# %%
with open('rumoureval-2019-training-data/train-key.json','rb') as f:
    keys = json.load(f)
with open('rumoureval-2019-training-data/dev-key.json','rb') as f:
    keys1 = json.load(f)

# %%
cou = []
for i in ids:
    try:
        labels.append(keys['subtaskaenglish'][i])
    except:
        cou.append(i) 
for i in cou:
    try:
        labels.append(keys1['subtaskaenglish'][i])
    except:
        pass

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(labels)
labels = le.transform(labels)

# %%
df = pd.DataFrame({
    'text': text,
    'label':labels
})
# df.to_csv('dataset.tsv','\t',index = False,header = False)

# %%
type(text)
# Out:
# list

# %%
from simpletransformers.model import TransformerModel
# Out:
# /home/omkar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/omkar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/omkar/.local/lib/python3.6/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
args = {
   'output_dir': 'output/',
   'cache_dir': 'cache/',
   'fp16': False,
   'fp16_opt_level': 'O1',
   'max_seq_length': 128,
   'train_batch_size': 8,
   'eval_batch_size': 8,
   'gradient_accumulation_steps': 1,
   'num_train_epochs': 3,
   'weight_decay': 0,
   'learning_rate': 3e-5,
   'adam_epsilon': 1e-8,
   'warmup_ratio': 0.06,
   'warmup_steps': 0,
   'max_grad_norm': 1.0,'logging_steps': 50,
   'evaluate_during_training': False,
   'save_steps': 2000,
   'eval_all_checkpoints': True,
   'use_tensorboard': True,'overwrite_output_dir': False,
   'reprocess_input_data': False,
    'num_labels' : 5
}

# %%
model = TransformerModel('bert','bert-base-cased',args=args)

# %%
train_df = pd.DataFrame(data)
model.train_model(train_df)
# Out:
# Features loaded from cache at cache/cached_train_bert_128_binary
# Epoch:   0%|          | 0/3 [00:00<?, ?it/s]
#
# Current iteration:   0%|          | 0/656 [00:00<?, ?it/s]

# %%
import numpy as np
a = np.array(df.values)

# %%
data = []
for i,val in df.iterrows():
    data.append(list([val['text'],val['label']]))

# %%
type(data[0][1])
# Out:
# int

# %%
import tensorflow as tf
tf.convert_to_tensor(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-00e5453e1a2c> in <module>
#       1 import tensorflow as tf
# ----> 2 tf.convert_to_tensor(df)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor(value, dtype, name, preferred_dtype, dtype_hint)
#    1085   preferred_dtype = deprecation.deprecated_argument_lookup(
#    1086       "dtype_hint", dtype_hint, "preferred_dtype", preferred_dtype)
# -> 1087   return convert_to_tensor_v2(value, dtype, preferred_dtype, name)
#    1088
#    1089
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1143       name=name,
#    1144       preferred_dtype=dtype_hint,
# -> 1145       as_ref=False)
#    1146
#    1147
#
# ...

# %%
data
# Out:
# [['@RealAlexJones @infowars No, no one credible told you anything like that.',
#   3],
#  ['@RealAlexJones @Trump4Hope Hopefully they will confirm what we docs have strongly suspected for a long time now. Organic brain dz. &amp;dementia',
#   3],
#  ['What? @LansMyers are u thinking about lining your windows? LOL.. @RealAlexJones',
#   0],
#  ["@RealAlexJones @KLSouth notice she did he economic speech &amp; we haven't seen her for days!",
#   0],
#  ['@thingfish69 @RealAlexJones @infowars He is clearly lying like all of his stories.',
#   0],
#  ['@RealAlexJones @infowars enjoy extinction.', 1],
#  ["@RealAlexJones SUNDAY EDITION! 'LIVE' IN 4...3...2... NOW!!! TUNE IN @Infowars! Today: #HillarysHealth #SorosHacked https://t.co/Wgy2QGy5LJ",
#   2],
#  ["@RealAlexJones @infowars The Trolls, Alex is bad he lies, he's nuts, tin foil, etc. And yet here you are kicking a dead dog ? Who's crazy ?",
#   0],
# ...

# %%
type(df['text'])
# Out:
# pandas.core.series.Series

# %%
df = pd.read_csv('dataset.tsv',sep='\t')

# %%
Tran

# %%
df.keys()
# Out:
# Index(['764952394157461504', '3',
#        '@RealAlexJones @infowars No, no one credible told you anything like that.'],
#       dtype='object')

# %%
TransformerModel()
